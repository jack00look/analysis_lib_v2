# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
B_freq = np.array([10, 7.61, 5.23, 2.85])
B_meas = np.array([14, 12.13, 9.75, 7.36])
plt.plot(B_freq, B_meas, '-o')
plt.xlim(0, 15)
plt.ylim(0, 15)
plt.xlabel('B_freq (mG)')
plt.ylabel('B_meas (mG)')
# Out:
# Text(0, 0.5, 'B_meas (mG)')
